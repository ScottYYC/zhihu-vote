# %% [markdown]
# # 抓取知乎某用户的动态信息

# %%
import requests
url = "https://www.zhihu.com/people/si-yan-70-89/answers"
headers = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.8',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Cookie':'q_c1=a2674c024ff3403ea4c90a9740cb3af7|1497874662000|1497874662000; d_c0="AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=|1498197022"; _zap=96ce5cce-01fe-4b9e-8576-25c6afdc4b06; q_c1=a2674c024ff3403ea4c90a9740cb3af7|1500518254000|1497874662000; r_cap_id="MzMyMDZhZWFmZjRhNDdhMmFlYTA4YTc4OWNhMTQ5MTI=|1500863580|f085376d211579163bb2edfbf63844ceea669f3e"; cap_id="NjBkOGI2MTU3YTc5NDMwZTgwY2M3ZGY5OWQzYTg4ZjA=|1500863580|c0614a15413d813ec53540a62e7410264df96711"; z_c0=Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab; _xsrf=211155c86bd992632330d28e6eeadbd0; aliyungf_tc=AQAAAItirCu19gUAxMheZeyYt6EQ+72g; __utma=51854390.1079280041.1501126785.1501126785.1501209790.2; __utmb=51854390.0.10.1501209790; __utmc=51854390; __utmz=51854390.1501126785.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utmv=51854390.100--|2=registration_date=20170302=1^3=entry_date=20170302=1; _xsrf=211155c86bd992632330d28e6eeadbd0',
    'Host':'www.zhihu.com',
    'Referer':'https://zhuanlan.zhihu.com/p/25198314',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.104 Safari/537.36'
}

# %%
resp = requests.get(url, headers=headers)

# %%
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '<!doctype html>\n<html lang="zh" data-reactroot="" data-reactid="1" data-react-checksum="-1683797985"><head data-reactid="2"><meta charset="utf-8" data-reactid="3"/><title data-react-helmet="true" data-reactid="4">飔桀 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1" data-reactid="5"/><meta name="renderer" content="webkit" data-reactid="6"/><meta name="force-rendering" content="webkit" data-reactid="7"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" data-reactid="8"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" data-reactid="9"/><meta data-react-helmet="true" name="apple-itunes-app" content="app-id=432274380,\n              app-argument=zhihu://people/si-yan-70-89" data-reactid="10"/><link rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/static/favicon.ico" data-reactid="11"/><link rel="dns-prefetch" href="//static.zhihu.com" data-reactid="12"/><link rel="d
# ...

# %% [markdown]
# # 对知乎用户的回答进行点赞

# %%
url_vote = 'https://www.zhihu.com/api/v4/answers/204705419/voters'
headers1 = {
    'accept':'application/json, text/plain, */*',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.8',
    'authorization':'Bearer Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab',
    'Connection':'keep-alive',
    'Content-Length':'13',
    'content-type':'application/json',
    'Cookie':'q_c1=a2674c024ff3403ea4c90a9740cb3af7|1497874662000|1497874662000; d_c0="AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=|1498197022"; _zap=96ce5cce-01fe-4b9e-8576-25c6afdc4b06; q_c1=a2674c024ff3403ea4c90a9740cb3af7|1500518254000|1497874662000; r_cap_id="MzMyMDZhZWFmZjRhNDdhMmFlYTA4YTc4OWNhMTQ5MTI=|1500863580|f085376d211579163bb2edfbf63844ceea669f3e"; cap_id="NjBkOGI2MTU3YTc5NDMwZTgwY2M3ZGY5OWQzYTg4ZjA=|1500863580|c0614a15413d813ec53540a62e7410264df96711"; z_c0=Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab; _xsrf=211155c86bd992632330d28e6eeadbd0; aliyungf_tc=AQAAAItirCu19gUAxMheZeyYt6EQ+72g; s-q=%E9%A3%94%E6%A1%80; s-i=1; sid=iplk2bk8; __utma=51854390.1079280041.1501126785.1501126785.1501209790.2; __utmb=51854390.0.10.1501209790; __utmc=51854390; __utmz=51854390.1501126785.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utmv=51854390.100--|2=registration_date=20170302=1^3=entry_date=20170302=1; _xsrf=211155c86bd992632330d28e6eeadbd0',
    'Host':'www.zhihu.com',
    'Origin':'https://www.zhihu.com',
    'Referer':'https://www.zhihu.com/people/si-yan-70-89/answers',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.104 Safari/537.36',
    'x-udid':'AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=',
    'x-xsrftoken':'211155c86bd992632330d28e6eeadbd0',
}
payload = {
    "type":"up"
}
resp_vote = requests.post(url_vote, headers=headers1, json=payload)

# %%
resp_vote.status_code
# Out:
# 200

# %% [markdown]
# # 给用户的所有回答点赞

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'accept':'application/json, text/plain, */*',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.8',
    'authorization':'Bearer Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab',
    'Connection':'keep-alive',
    'Cookie':'q_c1=a2674c024ff3403ea4c90a9740cb3af7|1497874662000|1497874662000; d_c0="AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=|1498197022"; _zap=96ce5cce-01fe-4b9e-8576-25c6afdc4b06; q_c1=a2674c024ff3403ea4c90a9740cb3af7|1500518254000|1497874662000; r_cap_id="MzMyMDZhZWFmZjRhNDdhMmFlYTA4YTc4OWNhMTQ5MTI=|1500863580|f085376d211579163bb2edfbf63844ceea669f3e"; cap_id="NjBkOGI2MTU3YTc5NDMwZTgwY2M3ZGY5OWQzYTg4ZjA=|1500863580|c0614a15413d813ec53540a62e7410264df96711"; z_c0=Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab; _xsrf=211155c86bd992632330d28e6eeadbd0; aliyungf_tc=AQAAAIjSgnFVrwEAX8leZS/PeUei/d8d; __utma=51854390.1079280041.1501126785.1501209790.1501255599.3; __utmb=51854390.0.10.1501255599; __utmc=51854390; __utmz=51854390.1501126785.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utmv=51854390.100--|2=registration_date=20170302=1^3=entry_date=20170302=1; _xsrf=211155c86bd992632330d28e6eeadbd0',
    'Host':'www.zhihu.com',
    'Referer':'https://www.zhihu.com/people/si-yan-70-89/answers',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.104 Safari/537.36',
    'x-udid':'AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=',
}

# %% [markdown]
# ## 首先获取知乎用户的所有回答的ID

# %%
url_list = []
for i in [0,20,40,60]:
    url = "https://www.zhihu.com/api/v4/members/si-yan-70-89/answers?include=data%5B*%5D.is_normal%2Cis_collapsed%2Cannotation_action%2Cannotation_detail%2Ccollapse_reason%2Ccollapsed_by%2Csuggest_edit%2Ccomment_count%2Ccan_comment%2Ccontent%2Cvoteup_count%2Creshipment_settings%2Ccomment_permission%2Cmark_infos%2Ccreated_time%2Cupdated_time%2Creview_info%2Crelationship.is_authorized%2Cvoting%2Cis_author%2Cis_thanked%2Cis_nothelp%2Cupvoted_followees%3Bdata%5B*%5D.author.badge%5B%3F(type%3Dbest_answerer)%5D.topics&offset={}&limit=20&sort_by=created".format(i)
    url_list.append(url)
# Out:
# 4
# https://www.zhihu.com/api/v4/members/si-yan-70-89/answers?include=data%5B*%5D.is_normal%2Cis_collapsed%2Cannotation_action%2Cannotation_detail%2Ccollapse_reason%2Ccollapsed_by%2Csuggest_edit%2Ccomment_count%2Ccan_comment%2Ccontent%2Cvoteup_count%2Creshipment_settings%2Ccomment_permission%2Cmark_infos%2Ccreated_time%2Cupdated_time%2Creview_info%2Crelationship.is_authorized%2Cvoting%2Cis_author%2Cis_thanked%2Cis_nothelp%2Cupvoted_followees%3Bdata%5B*%5D.author.badge%5B%3F(type%3Dbest_answerer)%5D.topics&offset=0&limit=20&sort_by=created
# ...

# %%
answerId = []
for url in url_list:
    resp = requests.get(url, headers=headers)
    dic = resp.json()
    for data in dic['data']:
        answerId.append(data['id'])

# %%
len(set(answerId))
# Out:
# 75

# %% [markdown]
# ## 写个循环批量点赞

# %%
url_vote_list = []
for id in answerId:
    url_vote_list.append('https://www.zhihu.com/api/v4/answers/{}/voters'.format(id))

# %%
headers1 = {
    'accept':'application/json, text/plain, */*',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'zh-CN,zh;q=0.8',
    'authorization':'Bearer Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab',
    'Connection':'keep-alive',
    'Content-Length':'13',
    'content-type':'application/json',
    'Cookie':'q_c1=a2674c024ff3403ea4c90a9740cb3af7|1497874662000|1497874662000; d_c0="AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=|1498197022"; _zap=96ce5cce-01fe-4b9e-8576-25c6afdc4b06; q_c1=a2674c024ff3403ea4c90a9740cb3af7|1500518254000|1497874662000; r_cap_id="MzMyMDZhZWFmZjRhNDdhMmFlYTA4YTc4OWNhMTQ5MTI=|1500863580|f085376d211579163bb2edfbf63844ceea669f3e"; cap_id="NjBkOGI2MTU3YTc5NDMwZTgwY2M3ZGY5OWQzYTg4ZjA=|1500863580|c0614a15413d813ec53540a62e7410264df96711"; z_c0=Mi4wQURDQ2FqRGNZd3NBQUFJYndmUDBDeGNBQUFCaEFsVk5ZT21jV1FEMkpYTEFZbU83eEVWb0pUQUhqRk9Rek1tNDlR|1500863584|88e3c3898f802b7b7972c196c61c46b94f62ddab; _xsrf=211155c86bd992632330d28e6eeadbd0; aliyungf_tc=AQAAAItirCu19gUAxMheZeyYt6EQ+72g; s-q=%E9%A3%94%E6%A1%80; s-i=1; sid=iplk2bk8; __utma=51854390.1079280041.1501126785.1501126785.1501209790.2; __utmb=51854390.0.10.1501209790; __utmc=51854390; __utmz=51854390.1501126785.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utmv=51854390.100--|2=registration_date=20170302=1^3=entry_date=20170302=1; _xsrf=211155c86bd992632330d28e6eeadbd0',
    'Host':'www.zhihu.com',
    'Origin':'https://www.zhihu.com',
    'Referer':'https://www.zhihu.com/people/si-yan-70-89/answers',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.104 Safari/537.36',
    'x-udid':'AAACG8Hz9AuPTt4DstMJhTU5ERJ4c5UsmUI=',
    'x-xsrftoken':'211155c86bd992632330d28e6eeadbd0',
}
payload = {
    "type":"neutral"
}
for url_vote in url_vote_list:
    resp_vote = requests.post(url_vote, headers=headers1, json=payload)

# %% [markdown]
# 实测...用以上代码点了几个赞后后面的回答就点不了赞了。
# 寻找原因，登入网页手动点赞时被系统提醒点赞过于频繁233333所以是被系统发现了吧。
# 看来仅仅用以上代码刷赞是行不通的。
